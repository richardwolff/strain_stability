# %%
import pandas as pd

# %%
df = pd.read_pickle("Poyet_collection_dates.pkl")

# %%
df = pd.read_csv("Poyet_SRA_report.txt",index_col=0,sep="\t")

# %%
df
# Out:
#                 sample_accession experiment_accession run_accession  tax_id  \
# study_accession
# PRJNA544527         SAMN11846275           SRX5976953    SRR9205532  328813
# PRJNA544527         SAMN11846276           SRX5976952    SRR9205533  328813
# PRJNA544527         SAMN11846277           SRX5976951    SRR9205534  328813
# PRJNA544527         SAMN11846353           SRX5976950    SRR9205535  328813
# PRJNA544527         SAMN11846352           SRX5976949    SRR9205536  328813
# ...                          ...                  ...           ...     ...
# PRJNA544527         SAMN11847106           SRX6045304    SRR9275561     820
# PRJNA544527         SAMN11847802           SRX6045303    SRR9275562  216816
# PRJNA544527         SAMN11847101           SRX6045302    SRR9275563     820
# PRJNA544527         SAMN11847102           SRX6045301    SRR9275564     820
# PRJNA544527         SAMN11847103           SRX6045300    SRR9275565     820
#
# ...
