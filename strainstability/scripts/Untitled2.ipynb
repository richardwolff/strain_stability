# %%
import pandas as pd
import matplotlib.pyplot as plt
import miscellaneous_utils as mu

# %%
host = "ao"

# %%
data_dir = f"/u/scratch/r/rwolff/Poyet_midas_output_spu/merged_midas_output/{host}"

# %%
spec_df = pd.read_csv(f"{data_dir}/species/relative_abundance.txt.bz2",index_col=0,sep="\t")

# %%
species = "Bacteroides_massiliensis_44749"

# %%
dates = mu.return_dates(host)

# %%
spec_ab = spec_df.loc[species]
spec_ab = spec_ab.loc[[d for d in dates.index if d in spec_ab.index]]
spec_ab
# Out:
# SRR9224065    0.000000
# SRR9224066    0.000000
# SRR9224067    0.000000
# SRR9224068    0.000000
# SRR9224069    0.000000
#                 ...
# SRR9224257    0.000071
# SRR9224472    0.000000
# SRR9224473    0.000000
# SRR9224470    0.000081
# SRR9224471    0.000000
# Name: Bacteroides_massiliensis_44749, Length: 70, dtype: float64

# %%
plt.plot(dates.loc[spec_ab.index],spec_ab.values)
plt.semilogy();

# %%
10/13
# Out:
# 0.7692307692307693

# %%
df = pd.read_csv("strains_am.csv",index_col=0)

# %%
df
# Out:
#                                       SRR9224037  SRR9224053  SRR9224054  \
# Phascolarctobacterium_sp_59817_A             NaN         NaN         NaN
# Barnesiella_intestinihominis_62208_A         NaN    0.026096    0.018421
# Ruminococcus_bicirculans_59300_A             NaN    0.036282         NaN
# Bacteroides_uniformis_57318_A           0.154365    0.117484    0.128052
# Ruminococcus_bromii_62047_A                  NaN    0.025039    0.019047
# Faecalibacterium_prausnitzii_57453_A         NaN         NaN         NaN
# Parabacteroides_merdae_56972_A          0.039650         NaN    0.016899
# Bacteroides_stercoris_56735_A           0.039934    0.090631    0.066675
# Eubacterium_rectale_56927_A             0.004868    0.005497    0.005647
# Eubacterium_rectale_56927_B             0.021908    0.018322    0.013177
# Bacteroides_xylanisolvens_57185_A       0.020019    0.020832    0.016801
# Bacteroides_xylanisolvens_57185_B       0.017159    0.095827    0.107529
# ...
