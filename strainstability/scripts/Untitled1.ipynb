# %%
#import slm_utils
import pandas as pd
import config
import slm_utils

import miscellaneous_utils as mu
import matplotlib.pyplot as plt

import seaborn as sns
import numpy as np
from matplotlib.lines import Line2D

from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset)
import os

color_mood = ["#a63a33","#f1c132","#3c414d","#d7d7de","#aaaaaa"]
# Out:
# /u/home/r/rwolff/.conda/envs/strain_stability_env/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: The mpl_toolkits.axes_grid module was deprecated in version 2.1. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist provies the same functionality instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
hmp_spcs=os.listdir("/u/home/r/rwolff/diversity_ecology/analysis/pi/HMP1-2/")[1:]

# %%
pi_W = {}
BH = {}
for spcs in hmp_spcs:
    
    pi_df_BH = pd.read_csv("/u/home/r/rwolff/diversity_ecology/analysis/pi/HMP1-2/%s/%s_pi.txt" % (spcs,spcs),index_col=0)
    if pi_df_BH.shape[0] > 10:
        BH[spcs] = pi_df_BH.values[np.triu_indices(n=pi_df_BH.values.shape[0],m=pi_df_BH.shape[1],k=1)]
        pi_W[spcs] = np.diag(pi_df_BH.values)

# %%
fig,ax = plt.subplots(figsize=(12,8))
bins = np.logspace(-5,-1.5,40)
ax.hist(pi_W["Bacteroides_vulgatus_57955"],bins=bins,zorder=20,alpha=.7,density=True)
bins = np.logspace(-4.1,-1,1000)
ax.hist(BH["Bacteroides_vulgatus_57955"],bins=bins,density=True)
ax.semilogx();

# %%
bins = np.logspace(-4.2,-1.5,50)

X=ax.hist(pi_W["Bacteroides_vulgatus_57955"],bins=bins,zorder=20,alpha=.7,density=True)
bins = np.logspace(-4.2,-1,100)

Y=ax.hist(BH["Bacteroides_vulgatus_57955"],bins=bins,density=True)

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.plot(X[1][1:],X[0])
ax.plot(Y[1][1:],7*Y[0])

ax.semilogx()
# Out:
# []
